# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 600

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto baquerizo moreno
# Processing Record 2 of Set 1 | tralee
# Processing Record 3 of Set 1 | port-aux-francais
# Processing Record 4 of Set 1 | port mathurin
# Processing Record 5 of Set 1 | grytviken
# Processing Record 6 of Set 1 | susuman
# Processing Record 7 of Set 1 | karratha
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | college
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | atafu village
# Processing Record 12 of Set 1 | longyearbyen
# Processing Record 13 of Set 1 | adamstown
# Processing Record 14 of Set 1 | waitangi
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | ta`u
# Processing Record 17 of Set 1 | jinchang
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | choibalsan
# Processing Record 20 of Set 1 | argostolion
# Processing Record 21 of Set 1 | naduvattam
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | gulf breeze
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | papatowai
# Processing Record 26 of Set 1 | tsiombe
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | kampene
# Processing Record 29 of Set 1 | tanabe
# Processing Record 30 of Set 1 | luderitz
# Processing Record 31 of Set 1 | el porvenir
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | nantucket
# Processing Record 34 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 35 of Set 1 | fale old settlement
# Processing Record 36 of Set 1 | margaret river
# Processing Record 37 of Set 1 | bilibino
# Processing Record 38 of Set 1 | carry-le-rouet
# Processing Record 39 of Set 1 | fortuna
# Processing Record 40 of Set 1 | invercargill
# Processing Record 41 of Set 1 | puerto natales
# Processing Record 42 of Set 1 | edinburgh of the seven seas
# Processing Record 43 of Set 1 | salahonda
# Processing Record 44 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 45 of Set 1 | buala
# Processing Record 46 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 47 of Set 1 | cabo san lucas
# Processing Record 48 of Set 1 | keflavik
# Processing Record 49 of Set 1 | barkly west
# Processing Record 50 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 0 of Set 2 | sitka
# Processing Record 1 of Set 2 | tiksi
# Processing Record 2 of Set 2 | west island
# Processing Record 3 of Set 2 | wailua homesteads
# Processing Record 4 of Set 2 | smithers
# Processing Record 5 of Set 2 | quellon
# Processing Record 6 of Set 2 | port elizabeth
# Processing Record 7 of Set 2 | punta del este
# Processing Record 8 of Set 2 | vorgashor
# Processing Record 9 of Set 2 | praia da vitoria
# Processing Record 10 of Set 2 | san antonio de pale
# Processing Record 11 of Set 2 | olonkinbyen
# Processing Record 12 of Set 2 | whitehorse
# Processing Record 13 of Set 2 | sao francisco de paula
# Processing Record 14 of Set 2 | ha'il
# Processing Record 15 of Set 2 | mariana
# Processing Record 16 of Set 2 | auki
# Processing Record 17 of Set 2 | kulia village
# City not found. Skipping...
# Processing Record 18 of Set 2 | aasiaat
# Processing Record 19 of Set 2 | isafjordur
# Processing Record 20 of Set 2 | timbuktu
# Processing Record 21 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 22 of Set 2 | wad rawah
# Processing Record 23 of Set 2 | berezovo
# Processing Record 24 of Set 2 | ciudad lazaro cardenas
# Processing Record 25 of Set 2 | blackmans bay
# Processing Record 26 of Set 2 | gadzhiyevo
# Processing Record 27 of Set 2 | thurgoona
# Processing Record 28 of Set 2 | badger
# Processing Record 29 of Set 2 | stanley
# Processing Record 30 of Set 2 | ushuaia
# Processing Record 31 of Set 2 | tura
# Processing Record 32 of Set 2 | kone
# Processing Record 33 of Set 2 | codrington
# Processing Record 34 of Set 2 | laguna
# Processing Record 35 of Set 2 | hawaiian paradise park
# Processing Record 36 of Set 2 | funafuti
# Processing Record 37 of Set 2 | palopo
# Processing Record 38 of Set 2 | enewetak
# Processing Record 39 of Set 2 | ayaguz
# City not found. Skipping...
# Processing Record 40 of Set 2 | ribeira grande
# Processing Record 41 of Set 2 | minas de marcona
# Processing Record 42 of Set 2 | balaipungut
# Processing Record 43 of Set 2 | saldanha
# Processing Record 44 of Set 2 | pesaro
# Processing Record 45 of Set 2 | mandalgovi
# Processing Record 46 of Set 2 | carahue
# Processing Record 47 of Set 2 | dobryanka
# Processing Record 48 of Set 2 | chibougamau
# Processing Record 49 of Set 2 | nikol'sk
# Processing Record 0 of Set 3 | mahajanga
# Processing Record 1 of Set 3 | merizo village
# Processing Record 2 of Set 3 | vorkuta
# Processing Record 3 of Set 3 | dalian
# Processing Record 4 of Set 3 | kasama
# Processing Record 5 of Set 3 | remire-montjoly
# Processing Record 6 of Set 3 | piti village
# Processing Record 7 of Set 3 | crane
# Processing Record 8 of Set 3 | jabor
# Processing Record 9 of Set 3 | trenggalek
# Processing Record 10 of Set 3 | champerico
# Processing Record 11 of Set 3 | selfoss
# Processing Record 12 of Set 3 | sao raimundo nonato
# Processing Record 13 of Set 3 | okha
# Processing Record 14 of Set 3 | dryden
# Processing Record 15 of Set 3 | meulaboh
# Processing Record 16 of Set 3 | laojunmiao
# Processing Record 17 of Set 3 | kruisfontein
# Processing Record 18 of Set 3 | ambodifotatra
# Processing Record 19 of Set 3 | iskateley
# Processing Record 20 of Set 3 | dwarka
# Processing Record 21 of Set 3 | st. john's
# Processing Record 22 of Set 3 | arteche
# Processing Record 23 of Set 3 | whakatane
# Processing Record 24 of Set 3 | georgetown
# Processing Record 25 of Set 3 | constantia
# Processing Record 26 of Set 3 | wuhai
# Processing Record 27 of Set 3 | paraiso
# Processing Record 28 of Set 3 | vadso
# Processing Record 29 of Set 3 | arraial do cabo
# Processing Record 30 of Set 3 | rikaze
# Processing Record 31 of Set 3 | pont rouge
# Processing Record 32 of Set 3 | belmonte
# Processing Record 33 of Set 3 | salinas
# Processing Record 34 of Set 3 | ketchikan
# Processing Record 35 of Set 3 | muynoq
# Processing Record 36 of Set 3 | kodiak
# Processing Record 37 of Set 3 | alice springs
# Processing Record 38 of Set 3 | kingston
# Processing Record 39 of Set 3 | hilo
# Processing Record 40 of Set 3 | ciro marina
# Processing Record 41 of Set 3 | saipan
# Processing Record 42 of Set 3 | dauphin
# Processing Record 43 of Set 3 | qaqortoq
# Processing Record 44 of Set 3 | iqaluit
# Processing Record 45 of Set 3 | talnakh
# Processing Record 46 of Set 3 | punta arenas
# Processing Record 47 of Set 3 | lebu
# Processing Record 48 of Set 3 | mossel bay
# Processing Record 49 of Set 3 | ust-nera
# Processing Record 0 of Set 4 | hinthada
# Processing Record 1 of Set 4 | aztec
# Processing Record 2 of Set 4 | ivybridge
# Processing Record 3 of Set 4 | tazacorte
# Processing Record 4 of Set 4 | san juan
# Processing Record 5 of Set 4 | puerto armuelles
# Processing Record 6 of Set 4 | tshabong
# Processing Record 7 of Set 4 | hammerfest
# Processing Record 8 of Set 4 | anaconda
# Processing Record 9 of Set 4 | sesheke
# Processing Record 10 of Set 4 | murun-kuren
# Processing Record 11 of Set 4 | benguela
# Processing Record 12 of Set 4 | mount pearl
# Processing Record 13 of Set 4 | fisterra
# Processing Record 14 of Set 4 | egilsstadir
# Processing Record 15 of Set 4 | trairi
# Processing Record 16 of Set 4 | gibraleon
# Processing Record 17 of Set 4 | callao
# Processing Record 18 of Set 4 | lompoc
# Processing Record 19 of Set 4 | altamira
# Processing Record 20 of Set 4 | inhambane
# Processing Record 21 of Set 4 | la ermita
# Processing Record 22 of Set 4 | terrace
# Processing Record 23 of Set 4 | pangkalpinang
# Processing Record 24 of Set 4 | klyuchi
# Processing Record 25 of Set 4 | lihue
# Processing Record 26 of Set 4 | kapa'a
# Processing Record 27 of Set 4 | muzayri'
# City not found. Skipping...
# Processing Record 28 of Set 4 | hithadhoo
# Processing Record 29 of Set 4 | topolobampo
# Processing Record 30 of Set 4 | oroqen zizhiqi
# Processing Record 31 of Set 4 | millerovo
# Processing Record 32 of Set 4 | freetown
# Processing Record 33 of Set 4 | harper
# Processing Record 34 of Set 4 | carnarvon
# Processing Record 35 of Set 4 | rio gallegos
# Processing Record 36 of Set 4 | vallenar
# Processing Record 37 of Set 4 | tripoli
# Processing Record 38 of Set 4 | kerman
# Processing Record 39 of Set 4 | mejit
# Processing Record 40 of Set 4 | bao loc
# City not found. Skipping...
# Processing Record 41 of Set 4 | devonport
# Processing Record 42 of Set 4 | ryotsu-minato
# Processing Record 43 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 44 of Set 4 | east london
# Processing Record 45 of Set 4 | port alfred
# Processing Record 46 of Set 4 | obo
# Processing Record 47 of Set 4 | port lincoln
# Processing Record 48 of Set 4 | portland
# Processing Record 49 of Set 4 | cudahy
# Processing Record 0 of Set 5 | nuku'alofa
# Processing Record 1 of Set 5 | necochea
# Processing Record 2 of Set 5 | muli
# Processing Record 3 of Set 5 | kirakira
# Processing Record 4 of Set 5 | bonthe
# Processing Record 5 of Set 5 | cabedelo
# Processing Record 6 of Set 5 | prado
# Processing Record 7 of Set 5 | cockburn town
# Processing Record 8 of Set 5 | lorengau
# Processing Record 9 of Set 5 | margate
# Processing Record 10 of Set 5 | yambio
# Processing Record 11 of Set 5 | mutare
# Processing Record 12 of Set 5 | kourou
# Processing Record 13 of Set 5 | mugia
# Processing Record 14 of Set 5 | seaside
# Processing Record 15 of Set 5 | vyazemskiy
# Processing Record 16 of Set 5 | alice
# Processing Record 17 of Set 5 | san jose village
# City not found. Skipping...
# Processing Record 18 of Set 5 | uturoa
# Processing Record 19 of Set 5 | neusiedl am see
# Processing Record 20 of Set 5 | la passe
# Processing Record 21 of Set 5 | hayma'
# City not found. Skipping...
# Processing Record 22 of Set 5 | greymouth
# Processing Record 23 of Set 5 | zambezi
# Processing Record 24 of Set 5 | anadyr
# Processing Record 25 of Set 5 | kinablangan
# Processing Record 26 of Set 5 | bredasdorp
# Processing Record 27 of Set 5 | mili
# Processing Record 28 of Set 5 | sur
# Processing Record 29 of Set 5 | mayuge
# Processing Record 30 of Set 5 | nampa
# Processing Record 31 of Set 5 | lensk
# Processing Record 32 of Set 5 | yarmouth
# Processing Record 33 of Set 5 | vilyuchinsk
# Processing Record 34 of Set 5 | sukhodol
# Processing Record 35 of Set 5 | impfondo
# Processing Record 36 of Set 5 | brodnica
# Processing Record 37 of Set 5 | nyurba
# Processing Record 38 of Set 5 | san patricio
# Processing Record 39 of Set 5 | el oro de hidalgo
# Processing Record 40 of Set 5 | quatre cocos
# Processing Record 41 of Set 5 | andergrove
# Processing Record 42 of Set 5 | xai-xai
# Processing Record 43 of Set 5 | cill airne
# Processing Record 44 of Set 5 | urazovo
# Processing Record 45 of Set 5 | villa mercedes
# Processing Record 46 of Set 5 | katabu
# Processing Record 47 of Set 5 | xilin hot
# Processing Record 48 of Set 5 | rio grande
# Processing Record 49 of Set 5 | san sebastian de la gomera
# Processing Record 0 of Set 6 | toliara
# Processing Record 1 of Set 6 | kavieng
# Processing Record 2 of Set 6 | kayangel
# Processing Record 3 of Set 6 | lezhe
# Processing Record 4 of Set 6 | mount gambier
# Processing Record 5 of Set 6 | siwa oasis
# Processing Record 6 of Set 6 | zag
# Processing Record 7 of Set 6 | afaahiti
# Processing Record 8 of Set 6 | broken hill
# Processing Record 9 of Set 6 | coos bay
# Processing Record 10 of Set 6 | utrik
# Processing Record 11 of Set 6 | sao gabriel da cachoeira
# Processing Record 12 of Set 6 | shendi
# Processing Record 13 of Set 6 | forio
# Processing Record 14 of Set 6 | vila velha
# Processing Record 15 of Set 6 | linxia chengguanzhen
# Processing Record 16 of Set 6 | la gi
# Processing Record 17 of Set 6 | hasaki
# Processing Record 18 of Set 6 | moundou
# Processing Record 19 of Set 6 | calvi
# Processing Record 20 of Set 6 | fortaleza
# Processing Record 21 of Set 6 | yanbu
# Processing Record 22 of Set 6 | pahrump
# Processing Record 23 of Set 6 | yuzhno-kurilsk
# Processing Record 24 of Set 6 | bengkulu
# Processing Record 25 of Set 6 | forster
# Processing Record 26 of Set 6 | tolanaro
# Processing Record 27 of Set 6 | ishtixon shahri
# City not found. Skipping...
# Processing Record 28 of Set 6 | port saint john's
# Processing Record 29 of Set 6 | nova vicosa
# Processing Record 30 of Set 6 | san matias
# Processing Record 31 of Set 6 | island harbour
# Processing Record 32 of Set 6 | tateyama
# Processing Record 33 of Set 6 | alaghsas
# Processing Record 34 of Set 6 | gordonvale
# Processing Record 35 of Set 6 | santa ana
# Processing Record 36 of Set 6 | las tablas
# Processing Record 37 of Set 6 | tofol
# Processing Record 38 of Set 6 | la mira
# Processing Record 39 of Set 6 | muroto-misakicho
# Processing Record 40 of Set 6 | martapura
# Processing Record 41 of Set 6 | canutama
# Processing Record 42 of Set 6 | ilulissat
# Processing Record 43 of Set 6 | zaterechnyy
# Processing Record 44 of Set 6 | pacific grove
# Processing Record 45 of Set 6 | hamilton
# Processing Record 46 of Set 6 | akureyri
# Processing Record 47 of Set 6 | belomorsk
# Processing Record 48 of Set 6 | flying fish cove
# Processing Record 49 of Set 6 | murzuq
# Processing Record 0 of Set 7 | san luis
# Processing Record 1 of Set 7 | inirida
# Processing Record 2 of Set 7 | la ronge
# Processing Record 3 of Set 7 | puerto aysen
# Processing Record 4 of Set 7 | obuase
# Processing Record 5 of Set 7 | dunedin
# Processing Record 6 of Set 7 | dolinsk
# Processing Record 7 of Set 7 | novaya igirma
# Processing Record 8 of Set 7 | baneh
# Processing Record 9 of Set 7 | tarauaca
# Processing Record 10 of Set 7 | puerto santa
# Processing Record 11 of Set 7 | udachny
# Processing Record 12 of Set 7 | horta
# Processing Record 13 of Set 7 | tucuma
# Processing Record 14 of Set 7 | kuqa
# Processing Record 15 of Set 7 | geraldton
# Processing Record 16 of Set 7 | tazovsky
# Processing Record 17 of Set 7 | hami
# Processing Record 18 of Set 7 | junin de los andes
# Processing Record 19 of Set 7 | turpan
# Processing Record 20 of Set 7 | dudinka
# Processing Record 21 of Set 7 | el calafate
# Processing Record 22 of Set 7 | motueka
# Processing Record 23 of Set 7 | farasan
# Processing Record 24 of Set 7 | vila franca do campo
# Processing Record 25 of Set 7 | kimbe
# Processing Record 26 of Set 7 | san fernando de apure
# Processing Record 27 of Set 7 | michigan city
# Processing Record 28 of Set 7 | wewak
# Processing Record 29 of Set 7 | faya-largeau
# Processing Record 30 of Set 7 | yangor
# City not found. Skipping...
# Processing Record 31 of Set 7 | salym
# Processing Record 32 of Set 7 | urangan
# Processing Record 33 of Set 7 | yurty
# Processing Record 34 of Set 7 | ouellah
# City not found. Skipping...
# Processing Record 35 of Set 7 | le lavandou
# Processing Record 36 of Set 7 | puerto la cruz
# Processing Record 37 of Set 7 | mvomero
# Processing Record 38 of Set 7 | lubango
# Processing Record 39 of Set 7 | rongelap
# Processing Record 40 of Set 7 | nar'yan-mar
# Processing Record 41 of Set 7 | naroda
# Processing Record 42 of Set 7 | namibe
# Processing Record 43 of Set 7 | klaksvik
# Processing Record 44 of Set 7 | howrah
# Processing Record 45 of Set 7 | huangshan
# Processing Record 46 of Set 7 | rudsar
# Processing Record 47 of Set 7 | okhotsk
# Processing Record 48 of Set 7 | sorong
# Processing Record 49 of Set 7 | fereydun kenar
# Processing Record 0 of Set 8 | chongwe
# Processing Record 1 of Set 8 | buka
# Processing Record 2 of Set 8 | newnham
# Processing Record 3 of Set 8 | koh kong
# Processing Record 4 of Set 8 | kidal
# Processing Record 5 of Set 8 | bomdila
# Processing Record 6 of Set 8 | anka
# Processing Record 7 of Set 8 | argo
# Processing Record 8 of Set 8 | lodeynoye pole
# Processing Record 9 of Set 8 | port moresby
# Processing Record 10 of Set 8 | palikir - national government center
# Processing Record 11 of Set 8 | khandyga
# Processing Record 12 of Set 8 | am djarass
# City not found. Skipping...
# Processing Record 13 of Set 8 | kolyshley
# Processing Record 14 of Set 8 | ijuw
# City not found. Skipping...
# Processing Record 15 of Set 8 | ephrata
# Processing Record 16 of Set 8 | tortoli
# Processing Record 17 of Set 8 | darnah
# Processing Record 18 of Set 8 | mont-laurier
# Processing Record 19 of Set 8 | ola
# Processing Record 20 of Set 8 | nabire
# Processing Record 21 of Set 8 | san pedro pochutla
# Processing Record 22 of Set 8 | camana
# Processing Record 23 of Set 8 | al kharijah
# Processing Record 24 of Set 8 | kirensk
# Processing Record 25 of Set 8 | badiyah
# Processing Record 26 of Set 8 | marrakesh
# Processing Record 27 of Set 8 | ariquemes
# Processing Record 28 of Set 8 | newport
# Processing Record 29 of Set 8 | as sulayyil
# Processing Record 30 of Set 8 | templin
# Processing Record 31 of Set 8 | cidreira
# Processing Record 32 of Set 8 | queenstown
# Processing Record 33 of Set 8 | crucecita
# Processing Record 34 of Set 8 | moussoro
# Processing Record 35 of Set 8 | rundu
# Processing Record 36 of Set 8 | ebon
# Processing Record 37 of Set 8 | aioun
# Processing Record 38 of Set 8 | nova xavantina
# Processing Record 39 of Set 8 | antsiranana
# Processing Record 40 of Set 8 | pyetrykaw
# Processing Record 41 of Set 8 | juneau
# Processing Record 42 of Set 8 | belokurikha
# Processing Record 43 of Set 8 | mehran
# Processing Record 44 of Set 8 | sittwe
# Processing Record 45 of Set 8 | saint-philippe
# Processing Record 46 of Set 8 | fannuj
# City not found. Skipping...
# Processing Record 47 of Set 8 | tommot
# Processing Record 48 of Set 8 | umm kaddadah
# Processing Record 49 of Set 8 | paradip garh
# Processing Record 0 of Set 9 | san luis de la loma
# Processing Record 1 of Set 9 | ar ruways
# Processing Record 2 of Set 9 | srinagar
# Processing Record 3 of Set 9 | paracuru
# Processing Record 4 of Set 9 | grootfontein
# Processing Record 5 of Set 9 | nadvoitsy
# Processing Record 6 of Set 9 | coquimbo
# Processing Record 7 of Set 9 | nikolayevsk-on-amure
# Processing Record 8 of Set 9 | bereznik
# Processing Record 9 of Set 9 | zeya
# Processing Record 10 of Set 9 | macusani
# Processing Record 11 of Set 9 | bandarbeyla
# Processing Record 12 of Set 9 | aykhal
# Processing Record 13 of Set 9 | kodinsk
# Processing Record 14 of Set 9 | novo aripuana
# Processing Record 15 of Set 9 | chapaev
# Processing Record 16 of Set 9 | taulaga
# Processing Record 17 of Set 9 | tarnogskiy gorodok
# Processing Record 18 of Set 9 | paka
# Processing Record 19 of Set 9 | hadibu
# Processing Record 20 of Set 9 | campbellton
# Processing Record 21 of Set 9 | pangoa
# Processing Record 22 of Set 9 | humaita
# Processing Record 23 of Set 9 | dickinson
# Processing Record 24 of Set 9 | gallivare
# City not found. Skipping...
# Processing Record 25 of Set 9 | waingapu
# Processing Record 26 of Set 9 | tafresh
# Processing Record 27 of Set 9 | tuba city
# Processing Record 28 of Set 9 | chiredzi
# Processing Record 29 of Set 9 | fort bragg
# Processing Record 30 of Set 9 | psachna
# Processing Record 31 of Set 9 | medyn'
# Processing Record 32 of Set 9 | camalu
# Processing Record 33 of Set 9 | bayan nur
# City not found. Skipping...
# Processing Record 34 of Set 9 | ocean shores
# Processing Record 35 of Set 9 | eenhana
# Processing Record 36 of Set 9 | chui
# Processing Record 37 of Set 9 | ivdel'
# Processing Record 38 of Set 9 | ouadda
# Processing Record 39 of Set 9 | pingnan
# Processing Record 40 of Set 9 | kertih
# Processing Record 41 of Set 9 | san angelo
# Processing Record 42 of Set 9 | santana
# Processing Record 43 of Set 9 | ankazobe
# Processing Record 44 of Set 9 | garachico
# Processing Record 45 of Set 9 | boende
# Processing Record 46 of Set 9 | la'ie
# Processing Record 47 of Set 9 | albertina
# Processing Record 48 of Set 9 | illizi
# Processing Record 49 of Set 9 | dzhetygara
# Processing Record 0 of Set 10 | usinsk
# Processing Record 1 of Set 10 | coyhaique
# Processing Record 2 of Set 10 | el haouaria
# Processing Record 3 of Set 10 | na wa
# Processing Record 4 of Set 10 | olyokminsk
# Processing Record 5 of Set 10 | isangel
# Processing Record 6 of Set 10 | fuvahmulah
# City not found. Skipping...
# Processing Record 7 of Set 10 | bedford
# Processing Record 8 of Set 10 | manta
# Processing Record 9 of Set 10 | isiolo
# Processing Record 10 of Set 10 | kerikeri
# Processing Record 11 of Set 10 | olavarria
# Processing Record 12 of Set 10 | guanica
# Processing Record 13 of Set 10 | bodo
# Processing Record 14 of Set 10 | yesilhisar
# Processing Record 15 of Set 10 | menongue
# Processing Record 16 of Set 10 | nova olimpia
# Processing Record 17 of Set 10 | bardaskan
# City not found. Skipping...
# Processing Record 18 of Set 10 | outapi
# City not found. Skipping...
# Processing Record 19 of Set 10 | el nido
# Processing Record 20 of Set 10 | caconda
# Processing Record 21 of Set 10 | djambala
# Processing Record 22 of Set 10 | brookings
# Processing Record 23 of Set 10 | broome
# Processing Record 24 of Set 10 | praia grande
# Processing Record 25 of Set 10 | christchurch
# Processing Record 26 of Set 10 | kalaleh
# Processing Record 27 of Set 10 | fonadhoo
# City not found. Skipping...
# Processing Record 28 of Set 10 | vreed-en-hoop
# Processing Record 29 of Set 10 | bardai
# Processing Record 30 of Set 10 | qal'at bishah
# City not found. Skipping...
# Processing Record 31 of Set 10 | rostov
# Processing Record 32 of Set 10 | new ulm
# Processing Record 33 of Set 10 | taltal
# Processing Record 34 of Set 10 | sant'antioco
# Processing Record 35 of Set 10 | mukah
# City not found. Skipping...
# Processing Record 36 of Set 10 | reggane
# Processing Record 37 of Set 10 | kerewan
# Processing Record 38 of Set 10 | balurghat
# Processing Record 39 of Set 10 | haiku-pauwela
# Processing Record 40 of Set 10 | guaruja
# Processing Record 41 of Set 10 | new norfolk
# Processing Record 42 of Set 10 | satupa'itea
# City not found. Skipping...
# Processing Record 43 of Set 10 | i-n-salah
# Processing Record 44 of Set 10 | shetpe
# Processing Record 45 of Set 10 | melekeok village
# Processing Record 46 of Set 10 | aitape
# Processing Record 47 of Set 10 | onguday
# Processing Record 48 of Set 10 | sao paulo de olivenca
# Processing Record 49 of Set 10 | nguigmi
# Processing Record 0 of Set 11 | tuapse
# Processing Record 1 of Set 11 | hohhot
# Processing Record 2 of Set 11 | bodden town
# Processing Record 3 of Set 11 | ebaye
# Processing Record 4 of Set 11 | tamanrasset
# Processing Record 5 of Set 11 | mukher
# Processing Record 6 of Set 11 | bereket
# Processing Record 7 of Set 11 | peniche
# Processing Record 8 of Set 11 | vrangel'
# Processing Record 9 of Set 11 | port glaud
# City not found. Skipping...
# Processing Record 10 of Set 11 | thunder bay
# Processing Record 11 of Set 11 | port douglas
# Processing Record 12 of Set 11 | khilok
# Processing Record 13 of Set 11 | inari
# Processing Record 14 of Set 11 | balikpapan
# Processing Record 15 of Set 11 | agat village
# Processing Record 16 of Set 11 | punta gorda
# Processing Record 17 of Set 11 | canico
# Processing Record 18 of Set 11 | aquiraz
# Processing Record 19 of Set 11 | banff
# Processing Record 20 of Set 11 | san pedro
# Processing Record 21 of Set 11 | magadan
# Processing Record 22 of Set 11 | kristiansund
# Processing Record 23 of Set 11 | nizhnyaya omka
# Processing Record 24 of Set 11 | tadmur
# Processing Record 25 of Set 11 | port augusta
# Processing Record 26 of Set 11 | ipueiras
# Processing Record 27 of Set 11 | tacuba
# Processing Record 28 of Set 11 | severo-yeniseyskiy
# Processing Record 29 of Set 11 | punta de bombon
# Processing Record 30 of Set 11 | berdyansk
# Processing Record 31 of Set 11 | bairnsdale
# Processing Record 32 of Set 11 | kiffa
# Processing Record 33 of Set 11 | linda
# Processing Record 34 of Set 11 | kamyzyak
# Processing Record 35 of Set 11 | akrehamn
# Processing Record 36 of Set 11 | luis moya
# Processing Record 37 of Set 11 | saint-pol-de-leon
# Processing Record 38 of Set 11 | itaituba
# Processing Record 39 of Set 11 | westport
# Processing Record 40 of Set 11 | cidade velha
# Processing Record 41 of Set 11 | oranjemund
# Processing Record 42 of Set 11 | general conesa
# Processing Record 43 of Set 11 | poronaysk
# Processing Record 44 of Set 11 | luwingu
# Processing Record 45 of Set 11 | bamboo flat
# Processing Record 46 of Set 11 | rome
# Processing Record 47 of Set 11 | narrabri
# Processing Record 48 of Set 11 | bonnyville
# Processing Record 49 of Set 11 | nieuw amsterdam
# Processing Record 0 of Set 12 | papao
# Processing Record 1 of Set 12 | kavaratti
# Processing Record 2 of Set 12 | chonchi
# Processing Record 3 of Set 12 | luanda
# Processing Record 4 of Set 12 | sinop
# Processing Record 5 of Set 12 | machico
# Processing Record 6 of Set 12 | lockwood
# Processing Record 7 of Set 12 | bad neuenahr-ahrweiler
# Processing Record 8 of Set 12 | ciudad insurgentes
# Processing Record 9 of Set 12 | labrador city
# Processing Record 10 of Set 12 | aktau
# Processing Record 11 of Set 12 | san rafael
# Processing Record 12 of Set 12 | daru
# Processing Record 13 of Set 12 | tchintabaraden
# Processing Record 14 of Set 12 | karachev
# Processing Record 15 of Set 12 | mabai
# Processing Record 16 of Set 12 | borogontsy
# Processing Record 17 of Set 12 | ouro preto do oeste
# Processing Record 18 of Set 12 | glazunovka
# Processing Record 19 of Set 12 | olgii
# City not found. Skipping...
# Processing Record 20 of Set 12 | aromashevo
# Processing Record 21 of Set 12 | mana
# Processing Record 22 of Set 12 | kutum
# Processing Record 23 of Set 12 | kilindoni
# Processing Record 24 of Set 12 | lhokseumawe
# Processing Record 25 of Set 12 | miyaly
# Processing Record 26 of Set 12 | kardla
# Processing Record 27 of Set 12 | al jawf
# Processing Record 28 of Set 12 | kaga bandoro
# Processing Record 29 of Set 12 | zvishavane
# Processing Record 30 of Set 12 | laayoune plage
# City not found. Skipping...
# Processing Record 31 of Set 12 | roccella ionica
# Processing Record 32 of Set 12 | bode saadu
# Processing Record 33 of Set 12 | dolores
# Processing Record 34 of Set 12 | cole harbour
# Processing Record 35 of Set 12 | mombetsu
# Processing Record 36 of Set 12 | timimoun
# Processing Record 37 of Set 12 | mpika
# Processing Record 38 of Set 12 | weno
# Processing Record 39 of Set 12 | malanje
# Processing Record 40 of Set 12 | dampit
# Processing Record 41 of Set 12 | pacocha
# Processing Record 42 of Set 12 | muisne
# Processing Record 43 of Set 12 | kangding
# Processing Record 44 of Set 12 | san isidro de curuguaty
# Processing Record 45 of Set 12 | zmeinogorsk
# Processing Record 46 of Set 12 | ji parana
# City not found. Skipping...
# Processing Record 47 of Set 12 | kolwezi
# Processing Record 48 of Set 12 | kuusamo
# Processing Record 49 of Set 12 | az zawr
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)


# Show Record Count
city_data_df.count()
# Out:
# City          570
# Lat           570
# Lng           570
# Max Temp      570
# Humidity      570
# Cloudiness    570
# Wind Speed    570
# Country       570
# Date          570
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  puerto baquerizo moreno  -0.9000 -89.6000     28.55        79          40
# 1                   tralee  52.2704  -9.7026     12.27        96         100
# 2        port-aux-francais -49.3500  70.2167      5.84        93          99
# 3            port mathurin -19.6833  63.4167     27.06        76           2
# 4                grytviken -54.2811 -36.5092     -0.44        73          19
#
#    Wind Speed Country        Date
# 0        4.12      EC  1712864827
# 1        3.54      IE  1712864869
# 2        5.44      TF  1712864870
# 3        4.40      MU  1712864870
# 4        5.43      GS  1712864824

# %%
# Export the City_Data into a csv
city_data_df.to_csv("cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                             City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 0        puerto baquerizo moreno  -0.9000 -89.6000     28.55        79
# 1                         tralee  52.2704  -9.7026     12.27        96
# 2              port-aux-francais -49.3500  70.2167      5.84        93
# 3                  port mathurin -19.6833  63.4167     27.06        76
# 4                      grytviken -54.2811 -36.5092     -0.44        73
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                40        4.12      EC  1712864827
# 1               100        3.54      IE  1712864869
# 2                99        5.44      TF  1712864870
# 3                 2        4.40      MU  1712864870
# 4                19        5.43      GS  1712864824

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.plot(city_data_df["Lat"], 
         city_data_df["Max Temp"],
         linestyle="none", 
         marker="o", 
         markeredgecolor="black", 
         markeredgewidth=0.75)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Max Latitude vs. Temperature (2022-10-18)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.plot(city_data_df["Lat"], 
         city_data_df["Humidity"],
         linestyle="none", 
         marker="o", 
         markeredgecolor="black", 
         markeredgewidth=0.75)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (2022-10-18)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.plot(city_data_df["Lat"], 
         city_data_df["Cloudiness"], 
         linestyle="none", 
         marker="o", 
         markeredgecolor="black", 
         markeredgewidth=0.75)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (2022-10-18)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.plot(city_data_df["Lat"], 
         city_data_df["Wind Speed"], 
         linestyle="none", 
         marker="o", 
         markeredgecolor="black", 
         markeredgewidth=0.75)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Wind Speed (2022-10-18)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression(x_values, y_values, x_c=.1, y_c=.9):
    slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq, xy=(x_c, y_c), xycoords='axes fraction', fontsize=15,color="red")
    plt.xlabel ("Latitude")
    plt.ylabel (y_values.name)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1              tralee  52.2704   -9.7026     12.27        96         100
# 5             susuman  62.7833  148.1667    -20.01       100          99
# 8             college  64.8569 -147.8028      3.93        58         100
# 9           jamestown  42.0970  -79.2353     20.77        85         100
# 11       longyearbyen  78.2186   15.6401    -15.09        72           0
#
#          Wind Speed Country        Date
# City_ID
# 1              3.54      IE  1712864869
# 5              0.45      RU  1712864870
# 8              2.06      US  1712864870
# 9              4.63      US  1712864871
# 11             5.14      SJ  1712864871

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                             City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        puerto baquerizo moreno  -0.9000  -89.6000     28.55        79
# 2              port-aux-francais -49.3500   70.2167      5.84        93
# 3                  port mathurin -19.6833   63.4167     27.06        76
# 4                      grytviken -54.2811  -36.5092     -0.44        73
# 6                       karratha -20.7377  116.8463     26.86        72
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                40        4.12      EC  1712864827
# 2                99        5.44      TF  1712864870
# 3                 2        4.40      MU  1712864870
# 4                19        5.43      GS  1712864824
# 6                38        3.00      AU  1712864845

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

linear_regression(x_values, y_values, 0.1, 0.1)
# Out:
# The r-value is: 0.7164145696246781

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

linear_regression(x_values, y_values, 0.4, 0.1)
# Out:
# The r-value is: 0.6543722053494165

# %% [markdown]
# **Discussion about the linear relationship:** The northern value is 0.7164, while the southern is 0.6543.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
linear_regression(x_values, y_values, 0.5, 0.1)
# Out:
# The r-value is: 0.11538285104661909

# %%
# Southern Hemisphere
x_value = southern_hemi_df ["Lat"]
y_value = southern_hemi_df ["Humidity"]
linear_regression(x_values, y_values, 0.5, 0.1)
# Out:
# The r-value is: 0.11538285104661909

# %% [markdown]
# **Discussion about the linear relationship:** The northern is 0.115 while the southern is 0.115 which makes them equal.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value = northern_hemi_df ["Lat"]
y_value = northern_hemi_df ["Cloudiness"]
linear_regression(x_values, y_value, 1, 0)
# Out:
# The r-value is: 0.02121459443284165

# %%
# Southern Hemisphere
x_value = southern_hemi_df ["Lat"]
y_value = southern_hemi_df ["Cloudiness"]
linear_regression(x_value, y_value, 0.1, 0.2 )
# Out:
# The r-value is: 0.06378422544659479

# %% [markdown]
# **Discussion about the linear relationship:** The northern is 0.021, while the southern is, 0.063 which makes the souther higher.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value = northern_hemi_df ["Lat"]
y_value = northern_hemi_df ["Wind Speed"]
linear_regression(x_value, y_value, 0.1, 0.9)
# Out:
# The r-value is: 0.0038712765499087825

# %%
# Southern Hemisphere
x_value = southern_hemi_df ["Lat"]
y_value = southern_hemi_df ["Wind Speed"]
linear_regression(x_value, y_value, 0.6, 0.9)
# Out:
# The r-value is: 0.10459619584781323

# %% [markdown]
# **Discussion about the linear relationship:** The northern is 0.0038 while the southern is , 0.104 which makes the southern higher.
